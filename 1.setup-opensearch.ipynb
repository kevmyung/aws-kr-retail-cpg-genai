# %% [markdown]
# # 필수 패키지 설정 및 OpenSearch 클러스터 생성 (약 40분 소요)
# >이 노트북은 SageMaker Studio* **`Python 3 (ipykernel)`** kernel 및 ml.t3.medium 인스턴스에서 테스트 되었습니다.
#
# ---
# ### 중요
# - 이 노트북은 Anthropic 의 Claude-v3 Model Access가 허용된 계정에서 실행할 수 있습니다.
# - Model Access가 없는 분은 노트북의 코드와 결과 만을 확인해주세요.
# - 실행 시 **"과금"** 이 발생이 되는 부분 유념 해주시기 바랍니다.
#
# ---

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain==0.1.11 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 1)) (0.1.11)
# Requirement already satisfied: opensearch-py==2.4.2 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (2.4.2)
# Requirement already satisfied: faiss-cpu==1.7.4 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (1.7.4)
# Requirement already satisfied: pdfplumber==0.10.3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (0.10.3)
# Requirement already satisfied: termcolor==2.4.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (2.4.0)
# Requirement already satisfied: opensearch_dsl==2.1.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (2.1.0)
# Requirement already satisfied: unstructured in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (0.12.6)
# Requirement already satisfied: pdf2image in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: boto3 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 9)) (1.28.64)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (10.2.0)
# Requirement already satisfied: streamlit in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (1.32.2)
# Requirement already satisfied: opencv-python==4.9.0.80 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (4.9.0.80)
# Requirement already satisfied: unstructured-inference==0.7.23 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 13)) (0.7.23)
# Requirement already satisfied: pikepdf==8.12.0 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 14)) (8.12.0)
# Requirement already satisfied: pypdf==4.0.1 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (4.0.1)
# Requirement already satisfied: unstructured.pytesseract==0.3.12 in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (0.3.12)
# Requirement already satisfied: pytesseract in /opt/conda/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (0.3.10)
# Requirement already satisfied: PyYAML>=5.3 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.25 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (0.0.29)
# Requirement already satisfied: langchain-core<0.2,>=0.1.29 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (0.1.33)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (0.1.31)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (1.10.13)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain==0.1.11->-r requirements.txt (line 1)) (8.2.3)
# Requirement already satisfied: urllib3>=1.26.18 in /opt/conda/lib/python3.10/site-packages (from opensearch-py==2.4.2->-r requirements.txt (line 2)) (1.26.18)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from opensearch-py==2.4.2->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.10/site-packages (from opensearch-py==2.4.2->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: certifi>=2022.12.07 in /opt/conda/lib/python3.10/site-packages (from opensearch-py==2.4.2->-r requirements.txt (line 2)) (2024.2.2)
# Requirement already satisfied: pdfminer.six==20221105 in /opt/conda/lib/python3.10/site-packages (from pdfplumber==0.10.3->-r requirements.txt (line 4)) (20221105)
# Requirement already satisfied: pypdfium2>=4.18.0 in /opt/conda/lib/python3.10/site-packages (from pdfplumber==0.10.3->-r requirements.txt (line 4)) (4.28.0)
# Requirement already satisfied: layoutparser[layoutmodels,tesseract] in /opt/conda/lib/python3.10/site-packages (from unstructured-inference==0.7.23->-r requirements.txt (line 13)) (0.3.4)
# Requirement already satisfied: python-multipart in /opt/conda/lib/python3.10/site-packages (from unstructured-inference==0.7.23->-r requirements.txt (line 13)) (0.0.9)
# Requirement already satisfied: huggingface-hub in /opt/conda/lib/python3.10/site-packages (from unstructured-inference==0.7.23->-r requirements.txt (line 13)) (0.21.1)
# Requirement already satisfied: onnx in /opt/conda/lib/python3.10/site-packages (from unstructured-inference==0.7.23->-r requirements.txt (line 13)) (1.16.0)
# Requirement already satisfied: onnxruntime<1.16 in /opt/conda/lib/python3.10/site-packages (from unstructured-inference==0.7.23->-r requirements.txt (line 13)) (1.15.1)
# Requirement already satisfied: transformers>=4.25.1 in /opt/conda/lib/python3.10/site-packages (from unstructured-inference==0.7.23->-r requirements.txt (line 13)) (4.31.0)
# Requirement already satisfied: rapidfuzz in /opt/conda/lib/python3.10/site-packages (from unstructured-inference==0.7.23->-r requirements.txt (line 13)) (3.6.1)
# Requirement already satisfied: Deprecated in /opt/conda/lib/python3.10/site-packages (from pikepdf==8.12.0->-r requirements.txt (line 14)) (1.2.14)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from pikepdf==8.12.0->-r requirements.txt (line 14)) (23.2)
# Requirement already satisfied: lxml>=4.8 in /opt/conda/lib/python3.10/site-packages (from pikepdf==8.12.0->-r requirements.txt (line 14)) (5.1.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from pdfminer.six==20221105->pdfplumber==0.10.3->-r requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in /opt/conda/lib/python3.10/site-packages (from pdfminer.six==20221105->pdfplumber==0.10.3->-r requirements.txt (line 4)) (42.0.5)
# Requirement already satisfied: backoff==2.2.1 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: beautifulsoup4==4.12.3 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (4.12.3)
# Requirement already satisfied: chardet==5.2.0 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (5.2.0)
# Requirement already satisfied: click==8.1.7 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (8.1.7)
# Requirement already satisfied: dataclasses-json-speakeasy==0.5.11 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (0.5.11)
# Requirement already satisfied: emoji==2.10.1 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (2.10.1)
# Requirement already satisfied: filetype==1.2.0 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (1.2.0)
# Requirement already satisfied: idna==3.6 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (3.6)
# Requirement already satisfied: joblib==1.3.2 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: jsonpath-python==1.0.6 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (1.0.6)
# Requirement already satisfied: langdetect==1.0.9 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (1.0.9)
# Requirement already satisfied: marshmallow==3.20.2 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (3.20.2)
# Requirement already satisfied: mypy-extensions==1.0.0 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (1.0.0)
# Requirement already satisfied: nltk==3.8.1 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (3.8.1)
# Requirement already satisfied: python-iso639==2024.2.7 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (2024.2.7)
# Requirement already satisfied: python-magic==0.4.27 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (0.4.27)
# Requirement already satisfied: regex==2023.12.25 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (2023.12.25)
# Requirement already satisfied: soupsieve==2.5 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (2.5)
# Requirement already satisfied: tabulate==0.9.0 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (0.9.0)
# Requirement already satisfied: tqdm==4.66.2 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (4.66.2)
# Requirement already satisfied: typing-extensions==4.9.0 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: typing-inspect==0.9.0 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (0.9.0)
# Requirement already satisfied: unstructured-client==0.18.0 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (0.18.0)
# Requirement already satisfied: wrapt==1.16.0 in /opt/conda/lib/python3.10/site-packages (from unstructured->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: botocore<1.32.0,>=1.31.64 in /opt/conda/lib/python3.10/site-packages (from boto3->-r requirements.txt (line 9)) (1.31.64)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3->-r requirements.txt (line 9)) (1.0.1)
# Requirement already satisfied: s3transfer<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from boto3->-r requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: altair<6,>=4.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 11)) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 11)) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 11)) (5.3.3)
# Requirement already satisfied: pandas<3,>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 11)) (2.1.4)
# Requirement already satisfied: protobuf<5,>=3.20 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 11)) (4.21.12)
# Requirement already satisfied: pyarrow>=7.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 11)) (12.0.1)
# Requirement already satisfied: rich<14,>=10.14.0 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 11)) (13.7.1)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 11)) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 11)) (3.1.42)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 11)) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 11)) (6.4)
# Requirement already satisfied: watchdog>=2.1.5 in /opt/conda/lib/python3.10/site-packages (from streamlit->-r requirements.txt (line 11)) (4.0.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.11->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.11->-r requirements.txt (line 1)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.11->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.11->-r requirements.txt (line 1)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.11->-r requirements.txt (line 1)) (1.9.4)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 11)) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /opt/conda/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 11)) (4.17.3)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 11)) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 11)) (4.0.11)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/conda/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.11->-r requirements.txt (line 1)) (2.4)
# Requirement already satisfied: anyio<5,>=3 in /opt/conda/lib/python3.10/site-packages (from langchain-core<0.2,>=0.1.29->langchain==0.1.11->-r requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/conda/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.11->-r requirements.txt (line 1)) (3.9.15)
# Requirement already satisfied: coloredlogs in /opt/conda/lib/python3.10/site-packages (from onnxruntime<1.16->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (15.0.1)
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime<1.16->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (23.5.26)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from onnxruntime<1.16->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (1.12)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit->-r requirements.txt (line 11)) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas<3,>=1.3.0->streamlit->-r requirements.txt (line 11)) (2024.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 11)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich<14,>=10.14.0->streamlit->-r requirements.txt (line 11)) (2.17.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.11->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers>=4.25.1->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (3.13.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.25.1->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers>=4.25.1->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (0.4.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (2023.6.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (1.11.4)
# Requirement already satisfied: iopath in /opt/conda/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (0.1.10)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (2.0.0.post101)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (0.15.2a0+072ec57)
# Requirement already satisfied: effdet in /opt/conda/lib/python3.10/site-packages (from layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (0.4.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.29->langchain==0.1.11->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3->langchain-core<0.2,>=0.1.29->langchain==0.1.11->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.10/site-packages (from cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber==0.10.3->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 11)) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->altair<6,>=4.0->streamlit->-r requirements.txt (line 11)) (2.1.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 11)) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit->-r requirements.txt (line 11)) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in /opt/conda/lib/python3.10/site-packages (from coloredlogs->onnxruntime<1.16->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (10.0)
# Requirement already satisfied: timm>=0.9.2 in /opt/conda/lib/python3.10/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (0.9.16)
# Requirement already satisfied: pycocotools>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (2.0.7)
# Requirement already satisfied: omegaconf>=2.0 in /opt/conda/lib/python3.10/site-packages (from effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (2.2.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (3.2.1)
# Requirement already satisfied: portalocker in /opt/conda/lib/python3.10/site-packages (from iopath->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (2.8.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->onnxruntime<1.16->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (1.3.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20221105->pdfplumber==0.10.3->-r requirements.txt (line 4)) (2.21)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/conda/lib/python3.10/site-packages (from omegaconf>=2.0->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (4.9.3)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (3.8.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->effdet->layoutparser[layoutmodels,tesseract]->unstructured-inference==0.7.23->-r requirements.txt (line 13)) (3.1.1)

# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
module_path = "."
sys.path.append(os.path.abspath(module_path))

# %%
import boto3
import uuid
import botocore
import time
from utils.ssm import parameter_store

# %% [markdown]
# # OpneSearch 클러스터 생성
# - 테스트를 위해 Dev=True로 설정해서 진행합니다. 이후 실제 사용 사에는 Dev=False로 해야 합니다.
#
# ### 선수 조건
# - 아래의 링크를 참조해서 OpenSearch Service 를 생성하고, opensearch_domain_endpoint, http_auth 를 복사해서, 아래 셀의 내용을 대체 하세요.
#     - [OpenSearch 생성 가이드](https://github.com/gonsoomoon-ml/Kor-LLM-On-SageMaker/blob/main/2-Lab02-QA-with-RAG/4.rag-fsi-data-workshop/TASK-4_OpenSearch_Creation_and_Vector_Insertion.ipynb)
# - 랭체인 오프서처 참고 자료
#     - [Langchain Opensearch](https://python.langchain.com/docs/integrations/vectorstores/opensearch)

# %%
DEV = True # True일 경우 1-AZ without standby로 생성, False일 경우 3-AZ with standby. 워크샵 목적일 때는 지나친 과금/리소스 방지를 위해 True로 설정하는 것을 권장
VERSION = "2.11" # OpenSearch Version (예: 2.7 / 2.9 / 2.11)

opensearch_user_id = "raguser"
opensearch_user_password = "MarsEarth1!"

# %%
# 0. OpenSearch 인증정보 ssm에 저장하기

region = boto3.Session().region_name
account_id = boto3.client("sts").get_caller_identity()["Account"]
opensearch = boto3.client('opensearch', region)
rand_str = uuid.uuid4().hex[:8]
domain_name = f'rag-hol-{rand_str}'

cluster_config_prod = {
    'InstanceCount': 3,
    'InstanceType': 'r6g.large.search',
    'ZoneAwarenessEnabled': True,
    'DedicatedMasterEnabled': True,
    'MultiAZWithStandbyEnabled': True,
    'DedicatedMasterType': 'r6g.large.search',
    'DedicatedMasterCount': 3
}

cluster_config_dev = {
    'InstanceCount': 1,
    'InstanceType': 'r6g.large.search',
    'ZoneAwarenessEnabled': False,
    'DedicatedMasterEnabled': False,
}


ebs_options = {
    'EBSEnabled': True,
    'VolumeType': 'gp3',
    'VolumeSize': 100,
}

advanced_security_options = {
    'Enabled': True,
    'InternalUserDatabaseEnabled': True,
    'MasterUserOptions': {
        'MasterUserName': opensearch_user_id,
        'MasterUserPassword': opensearch_user_password
    }
}

ap = f'{{\"Version\":\"2012-10-17\",\"Statement\":[{{\"Effect\":\"Allow\",\"Principal\":{{\"AWS\":\"*\"}},\"Action\":\"es:*\",\"Resource\":\"arn:aws:es:{region}:{account_id}:domain\/{domain_name}\/*\"}}]}}'

if DEV:
    cluster_config = cluster_config_dev
else:
    cluster_config = cluster_config_prod

response = opensearch.create_domain(
    DomainName=domain_name,
    EngineVersion=f'OpenSearch_{VERSION}',
    ClusterConfig=cluster_config,
    AccessPolicies=ap,
    EBSOptions=ebs_options,
    AdvancedSecurityOptions=advanced_security_options,
    NodeToNodeEncryptionOptions={'Enabled': True},
    EncryptionAtRestOptions={'Enabled': True},
    DomainEndpointOptions={'EnforceHTTPS': True}
)

# %%
# %%time

# 1. OpenSearch 설치

def wait_for_domain_creation(domain_name):
    try:
        response = opensearch.describe_domain(
            DomainName=domain_name
        )
        # Every 60 seconds, check whether the domain is processing.
        while 'Endpoint' not in response['DomainStatus']:
            print('Creating Opensearch domain...')
            time.sleep(60)
            response = opensearch.describe_domain(
                DomainName=domain_name)

        # Once we exit the loop, the domain is ready for ingestion.
        endpoint = response['DomainStatus']['Endpoint']
        print('Domain endpoint ready to receive data: ' + endpoint)
    except botocore.exceptions.ClientError as error:
        if error.response['Error']['Code'] == 'ResourceNotFoundException':
            print('Domain not found.')
        else:
            raise error

wait_for_domain_creation(domain_name)

response = opensearch.describe_domain(DomainName=domain_name)
opensearch_domain_endpoint = f"https://{response['DomainStatus']['Endpoint']}"

# 2. OpenSearch 인증정보 ssm에 저장하기

region=boto3.Session().region_name
pm = parameter_store(region)

pm.put_params(
    key="opensearch_domain_endpoint",
    value=f'{opensearch_domain_endpoint}',
    overwrite=True,
    enc=False
)

pm.put_params(
    key="opensearch_user_id",
    value=f'{opensearch_user_id}',
    overwrite=True,
    enc=False
)

pm.put_params(
    key="opensearch_user_password",
    value=f'{opensearch_user_password}',
    overwrite=True,
    enc=True
)

# 3. 한국어 분석을 위한 노리(Nori) 플러그인 설치

nori_pkg_id = {}
nori_pkg_id['us-east-1'] = {
    '2.3': 'G196105221',
    '2.5': 'G240285063',
    '2.7': 'G16029449', 
    '2.9': 'G60209291',
    '2.11': 'G181660338'
}

nori_pkg_id['us-west-2'] = {
    '2.3': 'G94047474',
    '2.5': 'G138227316',
    '2.7': 'G182407158', 
    '2.9': 'G226587000',
    '2.11': 'G79602591'
}

pkg_response = opensearch.associate_package(
    PackageID=nori_pkg_id[region][VERSION], # nori plugin
    DomainName=domain_name
)

def wait_for_associate_package(domain_name, max_results=1):

    response = opensearch.list_packages_for_domain(
        DomainName=domain_name,
        MaxResults=1
    )
    # Every 60 seconds, check whether the domain is processing.
    while response['DomainPackageDetailsList'][0]['DomainPackageStatus'] == "ASSOCIATING":
        print('Associating packages...')
        time.sleep(60)
        response = opensearch.list_packages_for_domain(
            DomainName=domain_name,
            MaxResults=1
        )

    print('Nori Plugin Associated!')

wait_for_associate_package(domain_name)
# Out:
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Creating Opensearch domain...
# Domain endpoint ready to receive data: search-rag-hol-b1c12dcc-6e5y7l5iniphi5mmhbh3w5gni4.us-east-1.es.amazonaws.com
# Parameter stored successfully.
# Parameter stored successfully.
# Parameter stored successfully.
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Associating packages...
# Nori Plugin Associated!
# CPU times: user 1.05 s, sys: 16.6 ms, total: 1.07 s
# Wall time: 47min 7s

# %%
print (pm.get_params(key="opensearch_domain_endpoint", enc=False))
print (pm.get_params(key="opensearch_user_id", enc=False))
print (pm.get_params(key="opensearch_user_password", enc=True))
# Out:
# https://search-rag-hol-b1c12dcc-6e5y7l5iniphi5mmhbh3w5gni4.us-east-1.es.amazonaws.com
# raguser
# MarsEarth1!
